# %% [markdown]
# # Matplotlib — Exercises
#
# **Companion to deck 04 (Matplotlib Basics).** Diagnose data with the right plot.
#
# Each problem ships a TODO cell + a manual check (look at the plot — no asserts for visual output) + a hint and a solution.
#
# <a href="https://colab.research.google.com/github/Petkub/MachineLearningLab/blob/main/colab_exercises/03_matplotlib.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = sns.load_dataset('titanic').rename(columns={
    'pclass': 'Pclass', 'sex': 'Sex', 'age': 'Age',
    'fare': 'Fare', 'survived': 'Survived', 'embarked': 'Embarked',
})
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df.shape)
df.head()

# %% [markdown]
# ---
# ## Problem 01 — distribution + bin-count reasoning
#
# A histogram's shape changes drastically with `bins=`. Plot **three histograms of `Age`** side by side, with `bins=4`, `bins=30`, `bins=200`. Label each subplot with its bin count.
#
# After running, **answer in your head** (no code):
# - Which one hides the structure (oversmoothed)?
# - Which one is too noisy (every bar is one passenger)?
# - Which one shows the right level of detail?
#
# There's no single right answer for `bins` — but the wrong answers are obvious once you see them all.

# %%
# TODO — make a 1x3 subplot showing 3 bin counts
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

# axes[0]: hist of Age with bins=4
# axes[1]: hist of Age with bins=30
# axes[2]: hist of Age with bins=200
# set_title on each — label with the bin count

plt.tight_layout()
plt.show()

# %% [markdown]
# <details><summary>Hint</summary>
#
# `plt.subplots(1, 3)` returns axes as a 1D array — index with `axes[i]` (no second index). Each subplot gets its own `.hist(data, bins=N)` and `.set_title(...)`. Watch:
# - 4 bins: distribution looks like a single bump — detail lost.
# - 30 bins: smooth curve, peak around 20s, tail to old age. Useful.
# - 200 bins: most bars 0 or 1 high. Noise, not signal.
#
# </details>

# %% [markdown]
# ---
# ## Problem 02 — class imbalance check
#
# Plot a bar chart of `Pclass` value counts. Sort tallest → shortest.
#
# **Decision:** is the data balanced? After plotting, save your answer (`'balanced'` or `'imbalanced'`) in `verdict` based on whether one class is more than 2x another.

# %%
# TODO
counts = ...    # value_counts of Pclass, sorted descending
verdict = ...   # 'balanced' or 'imbalanced' — based on counts.max() / counts.min()

plt.figure(figsize=(6, 4))
# bar plot from counts
plt.show()

print('counts:', counts.to_dict(), '| verdict:', verdict)

# %% [markdown]
# <details><summary>Hint</summary>
#
# Pandas Series have a built-in counter that returns categories sorted by frequency by default. Series also have a `.plot` accessor with a `.bar()` sub-method. Compare `counts.max()` to `counts.min()` to decide balance — a 2× ratio is a common cutoff.
#
# </details>

# %% [markdown]
# ---
# ## Problem 03 — relationship between two variables, colored by class
#
# Scatter plot: `Age` (x) vs `Fare` (y). Color each dot by `Survived` (0 = red, 1 = blue). Use `alpha=0.5` so dots don't pile up. Add a colorbar.
#
# **Eyeball goal:** is there visual separation between survived / didn't?

# %%
# TODO
plt.figure(figsize=(8, 5))
# plt.scatter(...)
# plt.colorbar()
plt.show()

# %% [markdown]
# <details><summary>Hint</summary>
#
# `plt.scatter` takes x and y as positional args, then several keyword args for visual encoding:
# - color array → `c=` (pass a Series with class labels, matplotlib maps colors automatically)
# - transparency → `alpha=`
# - color scheme for the `c` mapping → `cmap=` (try `'coolwarm'` for binary classes)
#
# A separate function call adds the colorbar afterwards.
#
# </details>

# %% [markdown]
# ---
# ## Problem 04 — outliers per group
#
# Boxplot Fare grouped by Pclass. Use `df.boxplot(column='Fare', by='Pclass')`.
#
# **Eyeball goal:** which class has the most extreme outliers? (Hint: it's the one with the most rich passengers.)

# %%
# TODO — one line for the boxplot
plt.figure(figsize=(8, 5))
# ...
plt.show()

# %% [markdown]
# <details><summary>Hint</summary>
#
# DataFrames have their own `.boxplot` method that takes a `column=` (what to measure) and `by=` (how to group). It does the per-group split for you. The auto-generated suptitle is usually ugly — clear it with `plt.suptitle('')` and set your own title afterwards.
#
# </details>

# %% [markdown]
# ---
# ## Problem 05 — diagnostic dashboard with subplots
#
# Build a 2×2 figure showing four diagnostics in one shot:
# - `[0, 0]` — hist of Age
# - `[0, 1]` — hist of Fare
# - `[1, 0]` — bar chart of Pclass counts
# - `[1, 1]` — scatter Age vs Fare
#
# Each subplot must have its own title.

# %%
# TODO
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# axes[0, 0].hist(...)
# axes[0, 0].set_title(...)

# ... fill the other 3 subplots ...

plt.tight_layout()
plt.show()

# %% [markdown]
# <details><summary>Hint</summary>
#
# `plt.subplots(rows, cols)` returns the figure plus a 2D array of `Axes` objects. Once you have `axes`, call methods **on the axes object**, not on `plt`:
# - `axes[i, j].hist(...)`
# - `axes[i, j].set_title('...')`
# - `axes[i, j].scatter(...)`
#
# For pandas plotting helpers like `value_counts().plot.bar()`, pass `ax=axes[i, j]` to redirect output to a specific axis.
#
# </details>

# %% [markdown]
# ---
# ## Problem 06 — fix the broken plot
#
# The cell below renders, but it's wrong. Find and fix **three bugs**.
#
# Hints to look for: missing `plt.show()`? wrong axis label? mixed-up x/y? confusing legend?

# %%
# BROKEN — fix three things
epochs = np.arange(1, 11)
train_loss = np.exp(-epochs / 3) + 0.05
val_loss   = np.exp(-epochs / 4) + 0.10 + 0.02 * (epochs - 5)**2 / 10

plt.plot(train_loss, epochs, label='train')   # bug 1: x and y swapped
plt.plot(val_loss, epochs)                     # bug 2: missing label
plt.xlabel('loss')
plt.ylabel('epoch')
plt.title('Training curve')
# bug 3: missing plt.legend() and plt.show()

# %% [markdown]
# <details><summary>Hint</summary>
#
# Three things wrong:
# 1. `plt.plot(a, b)` puts `a` on x and `b` on y — check which series belongs on which axis given the labels.
# 2. The legend builds from `label=` keywords — every line that should appear in it needs one.
# 3. Two function calls were forgotten at the end. One enables the legend, one actually displays the figure.
#
# </details>

# %% [markdown]
# ---
# ## Solutions (don't peek too early)
#
# <details><summary>Show all solutions</summary>
#
# ```python
# # Q1 — bin-count reasoning
# fig, axes = plt.subplots(1, 3, figsize=(15, 4))
# for ax, b in zip(axes, [4, 30, 200]):
#     ax.hist(df['Age'], bins=b)
#     ax.set_title(f'bins={b}')
# plt.tight_layout(); plt.show()
# # Verdict: 4 too coarse, 200 too noisy, 30 just right.
#
# # Q2 — bar
# counts = df['Pclass'].value_counts()
# verdict = 'imbalanced' if counts.max() / counts.min() > 2 else 'balanced'
# counts.plot.bar(figsize=(6, 4))
# plt.title('Pclass counts'); plt.ylabel('count')
# plt.show()
#
# # Q3 — scatter colored
# plt.figure(figsize=(8, 5))
# plt.scatter(df['Age'], df['Fare'], c=df['Survived'], alpha=0.5, cmap='coolwarm')
# plt.xlabel('Age'); plt.ylabel('Fare')
# plt.colorbar(label='Survived')
# plt.show()
#
# # Q4 — boxplot per group
# df.boxplot(column='Fare', by='Pclass', figsize=(8, 5))
# plt.suptitle('')
# plt.title('Fare by Pclass')
# plt.show()
#
# # Q5 — subplots
# fig, axes = plt.subplots(2, 2, figsize=(12, 8))
# axes[0, 0].hist(df['Age'], bins=30); axes[0, 0].set_title('Age')
# axes[0, 1].hist(df['Fare'], bins=30); axes[0, 1].set_title('Fare')
# df['Pclass'].value_counts().plot.bar(ax=axes[1, 0]); axes[1, 0].set_title('Pclass')
# axes[1, 1].scatter(df['Age'], df['Fare'], alpha=0.4); axes[1, 1].set_title('Age vs Fare')
# plt.tight_layout(); plt.show()
#
# # Q6 — fixes
# plt.plot(epochs, train_loss, label='train')   # x then y
# plt.plot(epochs, val_loss, label='val')       # added label
# plt.xlabel('epoch'); plt.ylabel('loss')
# plt.title('Training curve')
# plt.legend(); plt.show()
# ```
# </details>
